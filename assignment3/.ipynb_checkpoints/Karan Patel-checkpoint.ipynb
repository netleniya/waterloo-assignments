# %%
import pandas as pd
import os

# %%
# Daily_shelter = pd.read_csv("C:/Users/karan/Documents/Daily shelter overnight occupancy.csv")
# COVID19_case = pd.read_csv("C:/Users/karan/Documents/COVID19 cases.csv")
# Climate_data = pd.read_csv("C:/Users/karan/Documents/en_climate_daily_ON_6158731_2021_P1D.csv")


# df1 = Daily_shelter.merge(COVID19_case)
# # df1.head()

# %%
df = pd.read_csv("C:/Users/karan/Documents/Pandas/Daily shelter overnight occupancy.csv")

files = (file for file in os.listdir('C:/Users/karan/Documents/Pandas'))

df1 = pd.DataFrame()

for file in files:
    df = pd.read_csv("C:/Users/karan/Documents/Pandas/"+file)
    df1 = pd.concat([df1,df])
    
df1.to_csv("df1.csv", index=False)

# %%
df1.head()
# Out:
#         Age Group  Assigned_ID Classification Client Gender  \
# 0  20 to 29 Years     265244.0       PROBABLE          MALE
# 1  50 to 59 Years     265245.0      CONFIRMED          MALE
# 2  30 to 39 Years     265246.0      CONFIRMED          MALE
# 3  40 to 49 Years     265247.0      CONFIRMED        FEMALE
# 4  30 to 39 Years     265248.0       PROBABLE       UNKNOWN
#
#   Currently Hospitalized Currently Intubated Currently in ICU  \
# 0                     No                  No               No
# 1                     No                  No               No
# 2                     No                  No               No
# 3                     No                  No               No
# 4                     No                  No               No
#
#           Episode Date Ever Hospitalized Ever Intubated  ... Total Snow (cm)  \
# 0  2022-01-14T00:00:00                No             No  ...             NaN
# ...

# %%
df1.drop(columns=['Ever Hospitalized','Ever Intubated','Ever in ICU','Currently Hospitalized','Currently Intubated','Currently in ICU','Outcome','Neighbourhood Name','Classification'],inplace=True)

df1.tail()

df1.rename(columns={'Reported Date': 'Date'}, inplace=True)
df1.rename(columns={'Ever Hospitalized': 'Hospitalized', 'Ever Intubated': 'Intubated', 'Ever in ICU': 'ICU'}, inplace=True)

# %%
df1.tail()
# Out:
#     Age Group  Assigned_ID Client Gender Episode Date  FSA  \
# 360       NaN          NaN           NaN          NaN  NaN
# 361       NaN          NaN           NaN          NaN  NaN
# 362       NaN          NaN           NaN          NaN  NaN
# 363       NaN          NaN           NaN          NaN  NaN
# 364       NaN          NaN           NaN          NaN  NaN
#
#     Outbreak Associated Date Source of Infection  _id  CAPACITY_ACTUAL_BED  \
# 360                 NaN  NaN                 NaN  NaN                  NaN
# 361                 NaN  NaN                 NaN  NaN                  NaN
# 362                 NaN  NaN                 NaN  NaN                  NaN
# 363                 NaN  NaN                 NaN  NaN                  NaN
# 364                 NaN  NaN                 NaN  NaN                  NaN
#
#      ...  Total Snow (cm)  Total Snow Flag  Total Precip (mm)  \
# 360  ...              4.6              NaN                3.6
# ...

# %%
df1.rename(columns={'LOCATION_POSTAL_CODE': 'POSTAL_CODE', 'Client Gender': 'Gender'}, inplace=True)
df1.head(20)
# Out:
#          Age Group  Assigned_ID   Gender         Episode Date  FSA  \
# 0   20 to 29 Years     265244.0     MALE  2022-01-14T00:00:00  M6H
# 1   50 to 59 Years     265245.0     MALE  2022-01-13T00:00:00  M6K
# 2   30 to 39 Years     265246.0     MALE  2022-01-08T00:00:00  M6G
# 3   40 to 49 Years     265247.0   FEMALE  2022-01-13T00:00:00  M6P
# 4   30 to 39 Years     265248.0  UNKNOWN  2022-01-14T00:00:00  M6K
# 5   20 to 29 Years     265249.0     MALE  2022-01-07T00:00:00  M1R
# 6   70 to 79 Years     265250.0   FEMALE  2022-01-13T00:00:00  M1K
# 7   50 to 59 Years     265251.0   FEMALE  2022-01-14T00:00:00  M4V
# 8   19 and younger     265252.0  UNKNOWN  2022-01-10T00:00:00  M5M
# 9   20 to 29 Years     265253.0     MALE  2021-12-28T00:00:00  M1K
# 10  30 to 39 Years     265254.0   FEMALE  2022-01-14T00:00:00  NaN
# 11  30 to 39 Years     265255.0     MALE  2021-12-31T00:00:00  M1M
# 12  60 to 69 Years     265256.0   FEMALE  2022-01-10T00:00:00  M3L
# ...

# %%
print(df1.columns.tolist())
# Out:
# ['Age Group', 'Assigned_ID', 'Gender', 'Episode Date', 'FSA', 'Outbreak Associated', 'Date', 'Source of Infection', '_id', 'CAPACITY_ACTUAL_BED', 'CAPACITY_ACTUAL_ROOM', 'CAPACITY_FUNDING_BED', 'CAPACITY_FUNDING_ROOM', 'CAPACITY_TYPE', 'LOCATION_ADDRESS', 'LOCATION_CITY', 'LOCATION_ID', 'LOCATION_NAME', 'POSTAL_CODE', 'LOCATION_PROVINCE', 'OCCUPANCY_DATE', 'OCCUPANCY_RATE_BEDS', 'OCCUPANCY_RATE_ROOMS', 'OCCUPIED_BEDS', 'OCCUPIED_ROOMS', 'ORGANIZATION_ID', 'ORGANIZATION_NAME', 'OVERNIGHT_SERVICE_TYPE', 'PROGRAM_AREA', 'PROGRAM_ID', 'PROGRAM_MODEL', 'PROGRAM_NAME', 'SECTOR', 'SERVICE_USER_COUNT', 'SHELTER_GROUP', 'SHELTER_ID', 'UNAVAILABLE_BEDS', 'UNAVAILABLE_ROOMS', 'UNOCCUPIED_BEDS', 'UNOCCUPIED_ROOMS', 'Longitude (x)', 'Latitude (y)', 'Station Name', 'Climate ID', 'Date/Time', 'Year', 'Month', 'Day', 'Data Quality', 'Max Temp (°C)', 'Max Temp Flag', 'Min Temp (°C)', 'Min Temp Flag', 'Mean Temp (°C)', 'Mean Temp Flag', 'Heat Deg Days (°C)', 'Heat Deg Days Flag', 'Cool Deg Days (°C)',
# ...

# %%
df1.drop(columns=['_id','Source of Infection'],inplace=True)

# %%
## Clean date and specified date format
df1['Date']=pd.to_datetime(df1.Date)


print(df1['Date'])
# Out:
# 0     2022-01-14
# 1     2022-01-14
# 2     2022-01-14
# 3     2022-01-14
# 4     2022-01-14
#          ...
# 360          NaT
# 361          NaT
# 362          NaT
# 363          NaT
# 364          NaT
# Name: Date, Length: 306887, dtype: datetime64[ns]

# %%
df1['Date'].isnull().values.any()
# Out:
# True

# %%
df1['Date'].isnull().values.sum()
# Out:
# 11783

# %%
df1['Date/Time']=pd.to_datetime(df1.Date)


print(df1['Date/Time'])
# Out:
# 0     2022-01-14
# 1     2022-01-14
# 2     2022-01-14
# 3     2022-01-14
# 4     2022-01-14
#          ...
# 360          NaT
# 361          NaT
# 362          NaT
# 363          NaT
# 364          NaT
# Name: Date/Time, Length: 306887, dtype: datetime64[ns]

# %%
df1['Date/Time'].isnull().values.sum()
# Out:
# 11783

# %%
df1.dropna(how='all')
# Out:
#           Age Group  Assigned_ID   Gender         Episode Date  FSA  \
# 0    20 to 29 Years     265244.0     MALE  2022-01-14T00:00:00  M6H
# 1    50 to 59 Years     265245.0     MALE  2022-01-13T00:00:00  M6K
# 2    30 to 39 Years     265246.0     MALE  2022-01-08T00:00:00  M6G
# 3    40 to 49 Years     265247.0   FEMALE  2022-01-13T00:00:00  M6P
# 4    30 to 39 Years     265248.0  UNKNOWN  2022-01-14T00:00:00  M6K
# ..              ...          ...      ...                  ...  ...
# 360             NaN          NaN      NaN                  NaN  NaN
# 361             NaN          NaN      NaN                  NaN  NaN
# 362             NaN          NaN      NaN                  NaN  NaN
# 363             NaN          NaN      NaN                  NaN  NaN
# 364             NaN          NaN      NaN                  NaN  NaN
#
#      Outbreak Associated       Date  CAPACITY_ACTUAL_BED  \
# 0               Sporadic 2022-01-14                  NaN
# ...

# %%
df1.head(60)
# Out:
#          Age Group  Assigned_ID   Gender         Episode Date  FSA  \
# 0   20 to 29 Years     265244.0     MALE  2022-01-14T00:00:00  M6H
# 1   50 to 59 Years     265245.0     MALE  2022-01-13T00:00:00  M6K
# 2   30 to 39 Years     265246.0     MALE  2022-01-08T00:00:00  M6G
# 3   40 to 49 Years     265247.0   FEMALE  2022-01-13T00:00:00  M6P
# 4   30 to 39 Years     265248.0  UNKNOWN  2022-01-14T00:00:00  M6K
# 5   20 to 29 Years     265249.0     MALE  2022-01-07T00:00:00  M1R
# 6   70 to 79 Years     265250.0   FEMALE  2022-01-13T00:00:00  M1K
# 7   50 to 59 Years     265251.0   FEMALE  2022-01-14T00:00:00  M4V
# 8   19 and younger     265252.0  UNKNOWN  2022-01-10T00:00:00  M5M
# 9   20 to 29 Years     265253.0     MALE  2021-12-28T00:00:00  M1K
# 10  30 to 39 Years     265254.0   FEMALE  2022-01-14T00:00:00  NaN
# 11  30 to 39 Years     265255.0     MALE  2021-12-31T00:00:00  M1M
# 12  60 to 69 Years     265256.0   FEMALE  2022-01-10T00:00:00  M3L
# ...

# %%
print(df)
# Out:
#      Longitude (x)  Latitude (y)    Station Name  Climate ID   Date/Time  \
# 0           -79.63         43.68  TORONTO INTL A     6158731  2021-01-01
# 1           -79.63         43.68  TORONTO INTL A     6158731  2021-01-02
# 2           -79.63         43.68  TORONTO INTL A     6158731  2021-01-03
# 3           -79.63         43.68  TORONTO INTL A     6158731  2021-01-04
# 4           -79.63         43.68  TORONTO INTL A     6158731  2021-01-05
# ..             ...           ...             ...         ...         ...
# 360         -79.63         43.68  TORONTO INTL A     6158731  2021-12-27
# 361         -79.63         43.68  TORONTO INTL A     6158731  2021-12-28
# 362         -79.63         43.68  TORONTO INTL A     6158731  2021-12-29
# 363         -79.63         43.68  TORONTO INTL A     6158731  2021-12-30
# 364         -79.63         43.68  TORONTO INTL A     6158731  2021-12-31
#
#      Year  Month  Day  Data Quality  Max Temp (°C)  ... Total Snow (cm)  \
# ...

# %% [markdown]
# # covid 19 date cleaning
